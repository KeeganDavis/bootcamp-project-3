# %%
import pandas as pd

# %%
emdat_df = pd.read_excel('../Resources/EM-DAT/public_emdat_2024-03-30.xlsx')
emdat_df['Disaster Year'] = emdat_df['DisNo.'].str.split('-', expand=True)[0]
emdat_df['Disaster Num'] = emdat_df['DisNo.'].str.split('-', expand=True)[1]
emdat_df['disasterno'] = emdat_df['Disaster Year'] + '-' + emdat_df['Disaster Num']
emdat_df = emdat_df[['disasterno', 'Disaster Subgroup', 'Disaster Type', 'Country', 'Region', 'Magnitude', 'Magnitude Scale', 'Latitude', 'Longitude', 'Start Year', 'Start Month',
                     'Start Day', 'Total Deaths', 'No. Injured', 'No. Affected', 'Total Affected', 'Insured Damage (\'000 US$)', 'Insured Damage, Adjusted (\'000 US$)',
                     'Total Damage (\'000 US$)', 'Total Damage, Adjusted (\'000 US$)']]
emdat_df.head()
# Out:
#   disasterno Disaster Group Disaster Subgroup Disaster Type  ISO   Country  \
# 0  1999-9388        Natural    Climatological       Drought  DJI  Djibouti
# 1  1999-9388        Natural    Climatological       Drought  SDN     Sudan
# 2  1999-9388        Natural    Climatological       Drought  SOM   Somalia
# 3  2000-0001  Technological         Transport          Road  AGO    Angola
# 4  2000-0002        Natural      Hydrological         Flood  AGO    Angola
#
#    Region  Magnitude Magnitude Scale  Latitude  ...  Start Month  Start Day  \
# 0  Africa        NaN             Km2       NaN  ...          6.0        NaN
# 1  Africa        NaN             Km2       NaN  ...          1.0        NaN
# 2  Africa        NaN             Km2       NaN  ...          1.0        NaN
# 3  Africa        NaN             NaN       NaN  ...          1.0       26.0
# 4  Africa    47000.0             Km2       NaN  ...          1.0        8.0
#
# ...

# %%
lat_lng_df = pd.read_csv('../Resources/EM-DAT/pend-gdis-1960-2018-disasterlocations.csv')
lat_lng_df.head()
# Out:
#     id  country iso3   gwno  year  geo_id  geolocation  level     adm1  \
# 0  109  Albania  ALB  339.0  2009     346  Ana E Malit      3  Shkoder
# 1  109  Albania  ALB  339.0  2009     351       Bushat      3  Shkoder
# 2  175   Angola  AGO  540.0  2001     760       Onjiva      3   Cunene
# 3  187   Angola  AGO  540.0  2009     710        Evale      3   Cunene
# 4  187   Angola  AGO  540.0  2009     749         Mupa      3   Cunene
#
#        adm2         adm3     location  historical hist_country disastertype  \
# 0  Shkodres  Ana E Malit  Ana E Malit           0          NaN        flood
# 1  Shkodres       Bushat       Bushat           0          NaN        flood
# 2  Cuanhama       Onjiva       Onjiva           0          NaN        flood
# 3  Cuanhama        Evale        Evale           0          NaN        flood
# 4   Cuvelai         Mupa         Mupa           0          NaN        flood
#
#   disasterno   latitude  longitude
# 0  2009-0631  42.020948  19.418317
# ...

# %%
merged_df = emdat_df.merge(lat_lng_df, on='disasterno')

merged_df = merged_df[['disasterno', 'Disaster Subgroup', 'Disaster Type', 'Country', 'Region', 'geolocation', 'Magnitude', 'Magnitude Scale', 'latitude', 'longitude', 'Start Year', 'Start Month',
                     'Total Deaths', 'No. Injured', 'No. Affected', 'Total Affected', 'Insured Damage (\'000 US$)', 'Insured Damage, Adjusted (\'000 US$)',
                     'Total Damage (\'000 US$)', 'Total Damage, Adjusted (\'000 US$)']]
merged_df.head(10)
# Out:
#   disasterno Disaster Subgroup Disaster Type   Country  Region  geolocation  \
# 0  1999-9388    Climatological       Drought  Djibouti  Africa      Kibungo
# 1  1999-9388    Climatological       Drought  Djibouti  Africa      Rugombo
# 2  1999-9388    Climatological       Drought  Djibouti  Africa      Rumonge
# 3  1999-9388    Climatological       Drought  Djibouti  Africa      Buganda
# 4  1999-9388    Climatological       Drought  Djibouti  Africa      Gihanga
# 5  1999-9388    Climatological       Drought  Djibouti  Africa     Bugabira
# 6  1999-9388    Climatological       Drought  Djibouti  Africa       Busoni
# 7  1999-9388    Climatological       Drought  Djibouti  Africa        Ntega
# 8  1999-9388    Climatological       Drought  Djibouti  Africa    Wag Himra
# 9  1999-9388    Climatological       Drought  Djibouti  Africa  Debub Wollo
#
#    Magnitude Magnitude Scale   latitude  longitude  Start Year  Start Month  \
# ...

# %%
no_drought_df = merged_df.loc[(merged_df['Disaster Type'] != 'Drought')]
no_drought_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 67466 entries, 234 to 71593
# Data columns (total 23 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   disasterno                           67466 non-null  object
#  1   Disaster Group                       67466 non-null  object
#  2   Disaster Subgroup                    67466 non-null  object
#  3   Disaster Type                        67466 non-null  object
#  4   ISO                                  67466 non-null  object
#  5   Country                              67466 non-null  object
#  6   Region                               67466 non-null  object
#  7   adm1                                 67466 non-null  object
#  8   geo_id                               67466 non-null  int64
#  9   Magnitude                            27828 non-null  float64
#  10  Magnitude Scale                      66497 non-null  object
# ...

# %%
# len(merged_df['disasterno'].unique())
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71634 entries, 0 to 71633
# Data columns (total 21 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   disasterno                           71634 non-null  object
#  1   Disaster Subgroup                    71634 non-null  object
#  2   Disaster Type                        71634 non-null  object
#  3   ISO                                  71634 non-null  object
#  4   Country                              71634 non-null  object
#  5   Region                               71634 non-null  object
#  6   adm1                                 71634 non-null  object
#  7   geo_id                               71634 non-null  int64
#  8   Magnitude                            28141 non-null  float64
#  9   latitude                             71634 non-null  float64
#  10  longitude                            71634 non-null  float64
# ...

# %%
merged_df.groupby('Disaster Type').count()
# Out:
#                      disasterno  Disaster Subgroup  Country  Region  \
# Disaster Type
# Drought                    4168               4168     4168    4168
# Earthquake                 2688               2688     2688    2688
# Extreme temperature       26896              26896    26896   26896
# Flood                     18181              18181    18181   18181
# Mass movement (dry)          17                 17       17      17
# Mass movement (wet)         657                657      657     657
# Storm                     18732              18732    18732   18732
# Volcanic activity           295                295      295     295
#
#                      geolocation  Magnitude  Magnitude Scale  latitude  \
# Disaster Type
# Drought                     4168        313             4168      4168
# Earthquake                  2688       2687             2688      2688
# Extreme temperature        26896      12430            26896     26896
# ...
